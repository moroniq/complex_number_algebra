# %%
#Complex Number Algebra - Show addition, multiplication, negation, and inversion of complex numbers in separate functions. 
#(Subtraction and division operations can be made with pairs of these operations.) 
# Print the results for each operation tested.

# %%
z1 = (3, 2)
z2 = (1, 4)

# %%
def addition(z1, z2):
    real = z1[0] + z2[0]      # dodaj części rzeczywiste
    imag = z1[1] + z2[1]      # dodaj części urojone
    print(f"{real} + {imag}i")

# %%
addition(z1, z2)
# Out:
# 4 + 6i

# %%
def multiplication(z1, z2):
    real = (z1[0]*z2[0] - z1[1]*z2[1]) # dodaj części rzeczywiste
    imag = (z1[0]*z2[1] + z1[1]*z2[0]) # dodaj części urojone
    print(f"{real} + {imag}i")

# %%
multiplication(z1, z2)
# Out:
# -5 + 14i

# %%
def negation(z1):
    real = -z1[0] #część rzeczywista
    imag = -z1[1] #część urojona
    sign = "+" if imag >= 0 else "-"
    print(f"{real}{sign}{abs(imag)}i")  #sign - plus lub minus zależnie od imag, abs - wartość bezwzględna

# %%
negation(z1)
# Out:
# -3-2i

# %%
def inversion(z1):
    real = (z1[0]/(z1[0]**2 + z1[1]**2)) #część rzeczywista
    imag = (-z1[1]/(z1[0]**2+ z1[1]**2)) #część urojona
    sign = "+" if imag >= 0 else "-"
    print(f"{round(real,2)}{sign}{round(abs(imag), 2)}i")  #sign - plus lub minus zależnie od imag, abs - wartość bezwzględna

# %%
inversion(z1)
# Out:
# 0.23-0.15i
